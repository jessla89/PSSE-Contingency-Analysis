# %% [markdown]
# ### Year 4 Topology 5 Contingency Analysis Reporting - Lower Limit Violation

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Bus Voltage Data

# %%
list_volt = []
list_gens = [0, 50, 100]
list_lsc = ['LLS','RLS','HLS']
list_gen_hydro = [400,500,600] #dry, average, wet hydological scenarios
list_gen_wind = [0,40,75] # for 3 wind gust scenarios
for gen in list_gens:
    for gen_hy in list_gen_hydro:
        for lsc in list_lsc:
            for gen_wi in list_gen_wind:
                file_out = 'savnw_sol_' + str(gen) +'_hy_' +str(gen_hy) +'_wi_' + str(gen_wi) +'_' + str(lsc)+'.xlsx'
                data_volt = pd.read_excel(file_out, sheet_name='Bus Voltage', usecols = ['BUS', 'RECORD', 'TYPE', 'MIN/DROP', 'MAX/RISE', 'CONTINGENCY',
                                        'BASE VOLTS', 'CONT VOLTS', 'DEVIATION', 'RANGE VIO', 'DEV VIO'] )
                data_vo = data_volt.dropna(how='all').reset_index(drop=True)
                data_vo['Scenario']= 'Solar = ' + str(gen) + ' MW, ' + 'Hydro = ' + str(gen_hy) + ' MW, ' + 'Wind = ' + str(gen_wi) + ' MW, '  + lsc.upper()
                list_volt.append(data_vo)
data_v = pd.concat(list_volt).reset_index(drop=True)

# %% [markdown]
# #### Bus voltage data wrangling

# %%
data_v = data_v.rename(columns={'BUS':'Bus', 
                                'CONTINGENCY':'Contingency',
                                'BASE VOLTS':'Base Voltage',                               
                                'CONT VOLTS':'Contingency Voltage',
                                'RANGE VIO' : 'Range Violation', 
                                'DEVIATION' : 'Deviation'})
data_v['Contingency'] = data_v['Contingency'].str.replace('&','\&')
data_v['Bus'] = data_v['Bus'].str.replace('_','\_')
data_v['Bus Number'] = data_v['Bus'].str.split(expand=True)[0]

# %% [markdown]
# #### Lower limit bus voltage violations

# %%
data_low = data_v[data_v['Contingency Voltage']<0.9].reset_index(drop=True)
print(len(data_low))
display(data_low.head())
# Out:
# 2712
#                               Bus RECORD   TYPE  MIN/DROP  MAX/RISE  \
# 0     103     SOLAR\_PV    13.800    ALL  RANGE      0.95      1.05
# 1      154     DOWNTN      230.00    ALL  RANGE      0.95      1.05
# 2      203     EAST230     230.00    ALL  RANGE      0.95      1.05
# 3      204     SUB500      500.00    ALL  RANGE      0.95      1.05
# 4      205     SUB230      230.00    ALL  RANGE      0.95      1.05
#
#                     Contingency  Base Voltage  Contingency Voltage  Deviation  \
# 0  SING OPN LIN   11 201-204(1)      1.000000             0.870981  -0.129019
# 1  SING OPN LIN   11 201-204(1)      0.972923             0.838778  -0.134145
# 2  SING OPN LIN   11 201-204(1)      0.999363             0.885454  -0.113909
# 3  SING OPN LIN   11 201-204(1)      0.991333             0.842910  -0.148423
# 4  SING OPN LIN   11 201-204(1)      0.980000             0.842910  -0.137090
#
#    Range Violation  DEV VIO                                        Scenario  \
# 0        -0.079019      NaN  Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, LLS
# 1        -0.111222      NaN  Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, LLS
# 2        -0.064546      NaN  Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, LLS
# 3        -0.107090      NaN  Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, LLS
# 4        -0.107090      NaN  Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, LLS
#
#   Bus Number
# 0        103
# 1        154
# 2        203
# 3        204
# 4        205

# %% [markdown]
# #### Reporting of Buses with lower voltage violations

# %%
L_scen = list(data_low['Scenario'].unique())
print(f'It was seen that for Topology 4, all the studied scenarios reported lower voltage limit violation.')
print('------------------------------------------------------------------------------------------------------------------------------------------------------')
for vlscen in L_scen:
    print(vlscen)
    # Extracting bus data with voltage less than 0.9 PU
    data_lscen = data_low[data_low['Scenario'] == vlscen]
    print(f'For the studied scenario {vlscen}, the bus(es) reporting lower emergency range violation(s) are the bus(es)',', '.join(data_lscen['Bus Number'].unique()),)
    # lower range violation latex table data reporting
    data_replv = data_lscen[['Bus Number','Contingency','Base Voltage', 'Contingency Voltage', 'Deviation', 'Range Violation']].reset_index(drop=True)
    
    unit_lowv = data_replv[data_replv['Contingency'].str.contains('UNIT')]
    if len(unit_lowv) != 0:
        unit_lv = unit_lowv.drop_duplicates(subset=['Bus Number'])
        for contlu in list(unit_lv['Contingency'].unique()):
            unit_cont = unit_lv[unit_lv['Contingency']==contlu]
            busesu = ', '.join(unit_cont['Bus Number'].unique())
            print(f'The bus(es) {busesu} reported violations for unit fault {contlu}')
       
    bus_lowv = data_replv[data_replv['Contingency'].str.contains('BUS')]
    if len(bus_lowv) != 0:
        bus_lv = bus_lowv.drop_duplicates(subset=['Bus Number'])
        for contlb in list(bus_lv['Contingency'].unique()):
            bus_cont = bus_lv[bus_lv['Contingency']==contlb]
            busesb = ', '.join(bus_cont['Bus Number'].unique())
            print(f'The bus(es) {busesb} reported violations for the bus fault {contlb}')
                    
    line_lowv = data_replv[data_replv['Contingency'].str.contains('SING OPN LIN')]
    if len(line_lowv) != 0:
        line_lv = line_lowv.drop_duplicates(subset=['Bus Number'])
        for contll in list(line_lv['Contingency'].unique()):
            line_cont = line_lv[line_lv['Contingency']==contll]
            busesl = ', '.join(line_cont['Bus Number'].unique())
            print(f'The bus(es) {busesl} reported violations for the single line open fault {contll}')
    print('------------------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# It was seen that for Topology 4, all the studied scenarios reported lower voltage limit violation.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, LLS
# For the studied scenario Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 203, 204, 205, 3008, 153, 3006, 3007, 3009, 3010, 3012
# The bus(es) 103, 154, 203, 204, 205, 3008 reported violations for the bus fault BUS 202
# The bus(es) 153, 3006, 3007, 3009, 3010, 3012 reported violations for the bus fault BUS 205
# The bus(es) 103, 154, 203, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   11 201-204(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 400 MW, Wind = 40 MW, LLS
# For the studied scenario Solar = 0 MW, Hydro = 400 MW, Wind = 40 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 203, 204, 205, 3008, 153, 3006, 3007, 3012
# The bus(es) 103, 154, 203, 204, 205, 3008 reported violations for the bus fault BUS 202
# The bus(es) 153, 3006, 3007, 3012 reported violations for the bus fault BUS 205
# The bus(es) 103, 154, 203, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   11 201-204(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 400 MW, Wind = 75 MW, LLS
# For the studied scenario Solar = 0 MW, Hydro = 400 MW, Wind = 75 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 203, 204, 205, 3008, 153, 3006, 3007, 3009, 3012
# The bus(es) 103, 154, 203, 204, 205, 3008 reported violations for the bus fault BUS 202
# The bus(es) 153, 3006, 3007, 3009, 3012 reported violations for the bus fault BUS 205
# The bus(es) 103, 154, 203, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   11 201-204(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, RLS
# For the studied scenario Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 205, 3007, 3008
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154, 205 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 400 MW, Wind = 40 MW, RLS
# For the studied scenario Solar = 0 MW, Hydro = 400 MW, Wind = 40 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 205, 3007, 3008
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154, 205 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 400 MW, Wind = 75 MW, RLS
# For the studied scenario Solar = 0 MW, Hydro = 400 MW, Wind = 75 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 205, 3007, 3008
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154, 205 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, HLS
# For the studied scenario Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 205, 3006, 3008, 3009, 3010, 3012, 152, 202, 203, 204, 3007, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 205 reported violations for the bus fault BUS 203
# The bus(es) 103, 204, 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 103, 153, 154, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 152, 202, 203, 204, 3007 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 400 MW, Wind = 40 MW, HLS
# For the studied scenario Solar = 0 MW, Hydro = 400 MW, Wind = 40 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 205, 3006, 3008, 3009, 3010, 3012, 152, 202, 203, 204, 3007, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 205 reported violations for the bus fault BUS 203
# The bus(es) 103, 204, 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 103, 153, 154, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 152, 202, 203, 204, 3007 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 400 MW, Wind = 75 MW, HLS
# For the studied scenario Solar = 0 MW, Hydro = 400 MW, Wind = 75 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 205, 3006, 3008, 3009, 3010, 3012, 204, 3007, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 205 reported violations for the bus fault BUS 203
# The bus(es) 103, 204, 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 103, 153, 154, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 500 MW, Wind = 0 MW, LLS
# For the studied scenario Solar = 0 MW, Hydro = 500 MW, Wind = 0 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 3007
# The bus(es) 3007 reported violations for the bus fault BUS 3005
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 500 MW, Wind = 40 MW, LLS
# For the studied scenario Solar = 0 MW, Hydro = 500 MW, Wind = 40 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 3007
# The bus(es) 3007 reported violations for the bus fault BUS 3005
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 500 MW, Wind = 75 MW, LLS
# For the studied scenario Solar = 0 MW, Hydro = 500 MW, Wind = 75 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 3007
# The bus(es) 3007 reported violations for the bus fault BUS 3005
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 500 MW, Wind = 0 MW, RLS
# For the studied scenario Solar = 0 MW, Hydro = 500 MW, Wind = 0 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 205, 103, 202, 203, 204, 3007, 3008
# The bus(es) 154 reported violations for the bus fault BUS 203
# The bus(es) 205, 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154, 205 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 202, 203, 204, 3007, 3008 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 500 MW, Wind = 40 MW, RLS
# For the studied scenario Solar = 0 MW, Hydro = 500 MW, Wind = 40 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 103, 202, 203, 204, 205, 3008, 3007
# The bus(es) 154 reported violations for the bus fault BUS 203
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 202, 203, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 500 MW, Wind = 75 MW, RLS
# For the studied scenario Solar = 0 MW, Hydro = 500 MW, Wind = 75 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 103, 202, 203, 204, 205, 3007, 3008, 3012
# The bus(es) 154 reported violations for the bus fault BUS 203
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 202, 203, 204, 205, 3007, 3008, 3012 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 500 MW, Wind = 0 MW, HLS
# For the studied scenario Solar = 0 MW, Hydro = 500 MW, Wind = 0 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 103, 153, 204, 205, 3006, 3007, 3008, 3009, 3010, 3012
# The bus(es) 154, 205 reported violations for the bus fault BUS 153
# The bus(es) 103, 204, 3008 reported violations for the bus fault BUS 203
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   4 151-152(1)
# The bus(es) 103, 153, 204, 205, 3006, 3007, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 500 MW, Wind = 40 MW, HLS
# For the studied scenario Solar = 0 MW, Hydro = 500 MW, Wind = 40 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 103, 153, 204, 205, 3006, 3007, 3008, 3009, 3010, 3012
# The bus(es) 154, 205 reported violations for the bus fault BUS 153
# The bus(es) 103, 204, 3008 reported violations for the bus fault BUS 203
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   4 151-152(1)
# The bus(es) 103, 153, 204, 205, 3006, 3007, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 500 MW, Wind = 75 MW, HLS
# For the studied scenario Solar = 0 MW, Hydro = 500 MW, Wind = 75 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 103, 153, 204, 205, 3006, 3007, 3008, 3009, 3010, 3012
# The bus(es) 154, 205 reported violations for the bus fault BUS 153
# The bus(es) 103, 204, 3008 reported violations for the bus fault BUS 203
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   4 151-152(1)
# The bus(es) 103, 153, 204, 205, 3006, 3007, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 600 MW, Wind = 0 MW, LLS
# For the studied scenario Solar = 0 MW, Hydro = 600 MW, Wind = 0 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 203, 204, 205, 3007, 3008
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154, 203, 204, 205 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 600 MW, Wind = 40 MW, LLS
# For the studied scenario Solar = 0 MW, Hydro = 600 MW, Wind = 40 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 203, 204, 205, 3007, 3008
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154, 203, 204, 205 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 600 MW, Wind = 75 MW, LLS
# For the studied scenario Solar = 0 MW, Hydro = 600 MW, Wind = 75 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 203, 204, 205, 3007, 3008
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154, 203, 204, 205 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 600 MW, Wind = 0 MW, RLS
# For the studied scenario Solar = 0 MW, Hydro = 600 MW, Wind = 0 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012, 3007, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 103, 204, 205, 3008 reported violations for the bus fault BUS 203
# The bus(es) 3007, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 600 MW, Wind = 40 MW, RLS
# For the studied scenario Solar = 0 MW, Hydro = 600 MW, Wind = 40 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012, 3007, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 103, 204, 205, 3008 reported violations for the bus fault BUS 203
# The bus(es) 3007, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 600 MW, Wind = 75 MW, RLS
# For the studied scenario Solar = 0 MW, Hydro = 600 MW, Wind = 75 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012, 3007, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 103, 204, 205, 3008 reported violations for the bus fault BUS 203
# The bus(es) 3007, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 600 MW, Wind = 0 MW, HLS
# For the studied scenario Solar = 0 MW, Hydro = 600 MW, Wind = 0 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3008
# The bus(es) 103, 154, 204, 205, 3008 reported violations for the bus fault BUS 153
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 600 MW, Wind = 40 MW, HLS
# For the studied scenario Solar = 0 MW, Hydro = 600 MW, Wind = 40 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3008
# The bus(es) 103, 154, 204, 205, 3008 reported violations for the bus fault BUS 153
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 0 MW, Hydro = 600 MW, Wind = 75 MW, HLS
# For the studied scenario Solar = 0 MW, Hydro = 600 MW, Wind = 75 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3008
# The bus(es) 103, 154, 204, 205, 3008 reported violations for the bus fault BUS 153
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 400 MW, Wind = 0 MW, LLS
# For the studied scenario Solar = 50 MW, Hydro = 400 MW, Wind = 0 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3008, 203, 3007, 206
# The bus(es) 103, 154, 203, 204, 205, 206, 3007, 3008 reported violations for unit fault UNIT 206(1)
# The bus(es) 103, 154, 203, 204, 205, 3008 reported violations for the bus fault BUS 202
# The bus(es) 3007 reported violations for the bus fault BUS 205
# The bus(es) 103, 154, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   11 201-204(1)
# The bus(es) 203, 3007 reported violations for the single line open fault SING OPN LIN   20 205-206(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 400 MW, Wind = 40 MW, LLS
# For the studied scenario Solar = 50 MW, Hydro = 400 MW, Wind = 40 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3008, 203, 3007, 206
# The bus(es) 103, 154, 203, 204, 205, 206, 3007, 3008 reported violations for unit fault UNIT 206(1)
# The bus(es) 103, 154, 203, 204, 205, 3008 reported violations for the bus fault BUS 202
# The bus(es) 3007 reported violations for the bus fault BUS 205
# The bus(es) 103, 154, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   11 201-204(1)
# The bus(es) 203, 3007 reported violations for the single line open fault SING OPN LIN   20 205-206(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 400 MW, Wind = 75 MW, LLS
# For the studied scenario Solar = 50 MW, Hydro = 400 MW, Wind = 75 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 203, 204, 205, 3008, 3007, 153, 3012, 206
# The bus(es) 103, 154, 203, 204, 205, 206, 3007, 3008 reported violations for unit fault UNIT 206(1)
# The bus(es) 103, 154, 203, 204, 205, 3008 reported violations for the bus fault BUS 202
# The bus(es) 153, 3007, 3012 reported violations for the bus fault BUS 205
# The bus(es) 103, 154, 203, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   11 201-204(1)
# The bus(es) 3007 reported violations for the single line open fault SING OPN LIN   20 205-206(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 400 MW, Wind = 0 MW, RLS
# For the studied scenario Solar = 50 MW, Hydro = 400 MW, Wind = 0 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 103, 152, 153, 203, 3005, 3006, 3007, 3008, 3009, 3010, 3012, 3018
# The bus(es) 103, 152, 153, 154, 203, 3005, 3006, 3007, 3008, 3009, 3010, 3012, 3018 reported violations for the bus fault BUS 205
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 400 MW, Wind = 40 MW, RLS
# For the studied scenario Solar = 50 MW, Hydro = 400 MW, Wind = 40 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 103, 152, 153, 203, 3005, 3006, 3007, 3008, 3009, 3010, 3012, 3018
# The bus(es) 103, 152, 153, 154, 203, 3005, 3006, 3007, 3008, 3009, 3010, 3012, 3018 reported violations for the bus fault BUS 205
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 400 MW, Wind = 75 MW, RLS
# For the studied scenario Solar = 50 MW, Hydro = 400 MW, Wind = 75 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 103, 152, 153, 202, 203, 3004, 3005, 3006, 3007, 3008, 3009, 3010, 3012, 3018
# The bus(es) 103, 152, 153, 154, 202, 203, 3004, 3005, 3006, 3007, 3008, 3009, 3010, 3012, 3018 reported violations for the bus fault BUS 205
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 400 MW, Wind = 0 MW, HLS
# For the studied scenario Solar = 50 MW, Hydro = 400 MW, Wind = 0 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 205, 3006, 3008, 3009, 3010, 3012, 202, 203, 204, 3007, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 103, 205, 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 103, 153, 154, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 202, 203, 204, 3007 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 400 MW, Wind = 40 MW, HLS
# For the studied scenario Solar = 50 MW, Hydro = 400 MW, Wind = 40 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 205, 3006, 3012, 103, 202, 203, 204, 3007, 3008, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 103, 205, 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154, 205, 3006, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 202, 203, 204, 3007, 3008 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 400 MW, Wind = 75 MW, HLS
# For the studied scenario Solar = 50 MW, Hydro = 400 MW, Wind = 75 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 205, 3006, 3012, 103, 202, 203, 204, 3007, 3008, 3009, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 103, 205, 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154, 205, 3006, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 202, 203, 204, 3007, 3008, 3009 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 500 MW, Wind = 0 MW, LLS
# For the studied scenario Solar = 50 MW, Hydro = 500 MW, Wind = 0 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 152, 153, 154, 202, 203, 3004, 3005, 3006, 3007, 3008, 3009, 3010, 3012, 3018
# The bus(es) 103, 152, 153, 154, 202, 203, 3004, 3005, 3006, 3007, 3008, 3009, 3010, 3012, 3018 reported violations for the bus fault BUS 205
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 500 MW, Wind = 40 MW, LLS
# For the studied scenario Solar = 50 MW, Hydro = 500 MW, Wind = 40 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 3007
# The bus(es) 3007 reported violations for the bus fault BUS 3005
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 500 MW, Wind = 75 MW, LLS
# For the studied scenario Solar = 50 MW, Hydro = 500 MW, Wind = 75 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3008, 3007, 206
# The bus(es) 103, 154, 204, 205, 206, 3008 reported violations for unit fault UNIT 206(1)
# The bus(es) 3007 reported violations for the bus fault BUS 3005
# The bus(es) 103, 154, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   20 205-206(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 500 MW, Wind = 0 MW, RLS
# For the studied scenario Solar = 50 MW, Hydro = 500 MW, Wind = 0 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 103, 203, 204, 205, 3008, 3007
# The bus(es) 154, 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 203, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 500 MW, Wind = 40 MW, RLS
# For the studied scenario Solar = 50 MW, Hydro = 500 MW, Wind = 40 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 103, 203, 204, 205, 3008, 3007
# The bus(es) 154, 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 203, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 500 MW, Wind = 75 MW, RLS
# For the studied scenario Solar = 50 MW, Hydro = 500 MW, Wind = 75 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 103, 203, 204, 205, 3008, 3007
# The bus(es) 154, 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 203, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 500 MW, Wind = 0 MW, HLS
# For the studied scenario Solar = 50 MW, Hydro = 500 MW, Wind = 0 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012
# The bus(es) 154, 205 reported violations for the bus fault BUS 153
# The bus(es) 103, 204 reported violations for the bus fault BUS 203
# The bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 500 MW, Wind = 40 MW, HLS
# For the studied scenario Solar = 50 MW, Hydro = 500 MW, Wind = 40 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012, 3007, 3018
# The bus(es) 154, 205 reported violations for the bus fault BUS 153
# The bus(es) 103, 204 reported violations for the bus fault BUS 203
# The bus(es) 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 500 MW, Wind = 75 MW, HLS
# For the studied scenario Solar = 50 MW, Hydro = 500 MW, Wind = 75 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012, 3007, 3018
# The bus(es) 154, 205 reported violations for the bus fault BUS 153
# The bus(es) 103, 204 reported violations for the bus fault BUS 203
# The bus(es) 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 600 MW, Wind = 0 MW, LLS
# For the studied scenario Solar = 50 MW, Hydro = 600 MW, Wind = 0 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 205, 3007, 3008
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154, 205 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 600 MW, Wind = 40 MW, LLS
# For the studied scenario Solar = 50 MW, Hydro = 600 MW, Wind = 40 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 205, 3007, 3008
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154, 205 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 600 MW, Wind = 75 MW, LLS
# For the studied scenario Solar = 50 MW, Hydro = 600 MW, Wind = 75 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 205, 3007, 3008
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154, 205 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 600 MW, Wind = 0 MW, RLS
# For the studied scenario Solar = 50 MW, Hydro = 600 MW, Wind = 0 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 205, 3006, 3008, 3009, 3010, 3012, 204, 3007, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 103, 204, 205 reported violations for the bus fault BUS 203
# The bus(es) 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 103, 153, 154, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 600 MW, Wind = 40 MW, RLS
# For the studied scenario Solar = 50 MW, Hydro = 600 MW, Wind = 40 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 205, 3006, 3012, 103, 204, 3007, 3008, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 103, 204, 205 reported violations for the bus fault BUS 203
# The bus(es) 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154, 205, 3006, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 600 MW, Wind = 75 MW, RLS
# For the studied scenario Solar = 50 MW, Hydro = 600 MW, Wind = 75 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 205, 3006, 3012, 103, 204, 3007, 3008, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 103, 204, 205 reported violations for the bus fault BUS 203
# The bus(es) 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154, 205, 3006, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 600 MW, Wind = 0 MW, HLS
# For the studied scenario Solar = 50 MW, Hydro = 600 MW, Wind = 0 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3007, 3008
# The bus(es) 103, 154, 204, 205 reported violations for the bus fault BUS 153
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 203
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 600 MW, Wind = 40 MW, HLS
# For the studied scenario Solar = 50 MW, Hydro = 600 MW, Wind = 40 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3007, 3008
# The bus(es) 103, 154, 204, 205 reported violations for the bus fault BUS 153
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 203
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 50 MW, Hydro = 600 MW, Wind = 75 MW, HLS
# For the studied scenario Solar = 50 MW, Hydro = 600 MW, Wind = 75 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3007, 3008
# The bus(es) 103, 154, 204, 205 reported violations for the bus fault BUS 153
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 203
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 400 MW, Wind = 0 MW, LLS
# For the studied scenario Solar = 100 MW, Hydro = 400 MW, Wind = 0 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 203, 3007, 3008, 206
# The bus(es) 103, 154, 203, 204, 205, 206, 3007, 3008 reported violations for unit fault UNIT 206(1)
# The bus(es) 103, 154, 203, 204, 205 reported violations for the bus fault BUS 202
# The bus(es) 3008 reported violations for the bus fault BUS 205
# The bus(es) 103, 154, 204, 205 reported violations for the single line open fault SING OPN LIN   11 201-204(1)
# The bus(es) 203, 3007, 3008 reported violations for the single line open fault SING OPN LIN   20 205-206(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 400 MW, Wind = 40 MW, LLS
# For the studied scenario Solar = 100 MW, Hydro = 400 MW, Wind = 40 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3008, 203, 3007, 206
# The bus(es) 103, 154, 204, 205, 206, 3008 reported violations for unit fault UNIT 206(1)
# The bus(es) 103, 154, 203, 204, 205 reported violations for the bus fault BUS 202
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 205
# The bus(es) 103, 154, 204, 205 reported violations for the single line open fault SING OPN LIN   11 201-204(1)
# The bus(es) 3008 reported violations for the single line open fault SING OPN LIN   20 205-206(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 400 MW, Wind = 75 MW, LLS
# For the studied scenario Solar = 100 MW, Hydro = 400 MW, Wind = 75 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3008, 203, 3007, 206
# The bus(es) 103, 154, 204, 205, 206, 3008 reported violations for unit fault UNIT 206(1)
# The bus(es) 103, 154, 203, 204, 205 reported violations for the bus fault BUS 202
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 205
# The bus(es) 103, 154, 204, 205 reported violations for the single line open fault SING OPN LIN   11 201-204(1)
# The bus(es) 3008 reported violations for the single line open fault SING OPN LIN   20 205-206(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 400 MW, Wind = 0 MW, RLS
# For the studied scenario Solar = 100 MW, Hydro = 400 MW, Wind = 0 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 203, 3005, 3006, 3007, 3008, 3009, 3010, 3012
# The bus(es) 103, 153, 154, 203, 3005, 3006, 3007, 3008, 3009, 3010, 3012 reported violations for the bus fault BUS 205
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 400 MW, Wind = 40 MW, RLS
# For the studied scenario Solar = 100 MW, Hydro = 400 MW, Wind = 40 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 203, 3005, 3006, 3007, 3008, 3009, 3010, 3012
# The bus(es) 103, 153, 154, 203, 3005, 3006, 3007, 3008, 3009, 3010, 3012 reported violations for the bus fault BUS 205
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 400 MW, Wind = 75 MW, RLS
# For the studied scenario Solar = 100 MW, Hydro = 400 MW, Wind = 75 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 203, 3005, 3006, 3007, 3008, 3009, 3010, 3012, 3018
# The bus(es) 103, 153, 154, 203, 3005, 3006, 3007, 3008, 3009, 3010, 3012, 3018 reported violations for the bus fault BUS 205
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 400 MW, Wind = 0 MW, HLS
# For the studied scenario Solar = 100 MW, Hydro = 400 MW, Wind = 0 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 205, 3006, 3009, 3010, 3012, 103, 202, 203, 204, 3007, 3008, 3018
# The bus(es) 103, 154, 205, 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154, 205, 3006, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 202, 203, 204, 3007, 3008 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 400 MW, Wind = 40 MW, HLS
# For the studied scenario Solar = 100 MW, Hydro = 400 MW, Wind = 40 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 205, 3006, 3012, 103, 202, 203, 204, 3007, 3008, 3018
# The bus(es) 103, 154, 205, 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154, 205, 3006, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 202, 203, 204, 3007, 3008 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 400 MW, Wind = 75 MW, HLS
# For the studied scenario Solar = 100 MW, Hydro = 400 MW, Wind = 75 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 205, 3006, 3012, 103, 202, 203, 204, 3007, 3008, 3018
# The bus(es) 103, 154, 205, 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154, 205, 3006, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 202, 203, 204, 3007, 3008 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 500 MW, Wind = 0 MW, LLS
# For the studied scenario Solar = 100 MW, Hydro = 500 MW, Wind = 0 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3008, 152, 153, 203, 3005, 3006, 3007, 3009, 3010, 3012, 3018, 206
# The bus(es) 103, 154, 204, 205, 206, 3008 reported violations for unit fault UNIT 206(1)
# The bus(es) 103, 152, 153, 154, 203, 3005, 3006, 3007, 3008, 3009, 3010, 3012, 3018 reported violations for the bus fault BUS 205
# The bus(es) 103, 154, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   20 205-206(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 500 MW, Wind = 40 MW, LLS
# For the studied scenario Solar = 100 MW, Hydro = 500 MW, Wind = 40 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3008, 152, 153, 202, 203, 3004, 3005, 3006, 3007, 3009, 3010, 3012, 3018, 206
# The bus(es) 103, 154, 204, 205, 206, 3008 reported violations for unit fault UNIT 206(1)
# The bus(es) 103, 152, 153, 154, 202, 203, 3004, 3005, 3006, 3007, 3008, 3009, 3010, 3012, 3018 reported violations for the bus fault BUS 205
# The bus(es) 103, 154, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   20 205-206(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 500 MW, Wind = 75 MW, LLS
# For the studied scenario Solar = 100 MW, Hydro = 500 MW, Wind = 75 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 154, 204, 205, 3008, 152, 153, 202, 203, 3004, 3005, 3006, 3007, 3009, 3010, 3012, 3018, 206
# The bus(es) 103, 154, 204, 205, 206, 3008 reported violations for unit fault UNIT 206(1)
# The bus(es) 103, 152, 153, 154, 202, 203, 3004, 3005, 3006, 3007, 3008, 3009, 3010, 3012, 3018 reported violations for the bus fault BUS 205
# The bus(es) 103, 154, 204, 205, 3008 reported violations for the single line open fault SING OPN LIN   20 205-206(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 500 MW, Wind = 0 MW, RLS
# For the studied scenario Solar = 100 MW, Hydro = 500 MW, Wind = 0 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 103, 203, 204, 205, 3007, 3008
# The bus(es) 154, 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 203, 204, 205 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 500 MW, Wind = 40 MW, RLS
# For the studied scenario Solar = 100 MW, Hydro = 500 MW, Wind = 40 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 103, 203, 205, 3007, 3008
# The bus(es) 154, 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 203, 205 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 500 MW, Wind = 75 MW, RLS
# For the studied scenario Solar = 100 MW, Hydro = 500 MW, Wind = 75 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 103, 203, 204, 205, 3007, 3008
# The bus(es) 154, 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 203, 204, 205 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 500 MW, Wind = 0 MW, HLS
# For the studied scenario Solar = 100 MW, Hydro = 500 MW, Wind = 0 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012, 3007, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 205 reported violations for the bus fault BUS 203
# The bus(es) 103, 204, 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 500 MW, Wind = 40 MW, HLS
# For the studied scenario Solar = 100 MW, Hydro = 500 MW, Wind = 40 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012, 3007, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 205 reported violations for the bus fault BUS 203
# The bus(es) 103, 204, 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 500 MW, Wind = 75 MW, HLS
# For the studied scenario Solar = 100 MW, Hydro = 500 MW, Wind = 75 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012, 3007, 3018
# The bus(es) 154 reported violations for the bus fault BUS 153
# The bus(es) 205 reported violations for the bus fault BUS 203
# The bus(es) 103, 204, 3007, 3008, 3018 reported violations for the bus fault BUS 3005
# The bus(es) 103, 153, 154, 204, 205, 3006, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 600 MW, Wind = 0 MW, LLS
# For the studied scenario Solar = 100 MW, Hydro = 600 MW, Wind = 0 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 3007, 3008
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 600 MW, Wind = 40 MW, LLS
# For the studied scenario Solar = 100 MW, Hydro = 600 MW, Wind = 40 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 3007, 3008
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 600 MW, Wind = 75 MW, LLS
# For the studied scenario Solar = 100 MW, Hydro = 600 MW, Wind = 75 MW, LLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 3007, 3008
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 600 MW, Wind = 0 MW, RLS
# For the studied scenario Solar = 100 MW, Hydro = 600 MW, Wind = 0 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 205, 3006, 3009, 3010, 3012, 103, 152, 202, 203, 204, 3007, 3008
# The bus(es) 154, 205 reported violations for the bus fault BUS 203
# The bus(es) 103, 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154, 205, 3006, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 152, 202, 203, 204, 3007, 3008 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 600 MW, Wind = 40 MW, RLS
# For the studied scenario Solar = 100 MW, Hydro = 600 MW, Wind = 40 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 205, 3006, 3012, 103, 152, 202, 203, 204, 3007, 3008, 3009, 3010
# The bus(es) 154, 205 reported violations for the bus fault BUS 203
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154, 205, 3006, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 152, 202, 203, 204, 3007, 3008, 3009, 3010 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 600 MW, Wind = 75 MW, RLS
# For the studied scenario Solar = 100 MW, Hydro = 600 MW, Wind = 75 MW, RLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 153, 154, 205, 3006, 3012, 103, 152, 202, 203, 204, 3007, 3008, 3009, 3010
# The bus(es) 154, 204, 205 reported violations for the bus fault BUS 203
# The bus(es) 3007, 3008 reported violations for the bus fault BUS 3005
# The bus(es) 153, 154, 205, 3006, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# The bus(es) 103, 152, 202, 203, 204, 3007, 3008, 3009, 3010 reported violations for the single line open fault SING OPN LIN   10 201-202(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 600 MW, Wind = 0 MW, HLS
# For the studied scenario Solar = 100 MW, Hydro = 600 MW, Wind = 0 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 103, 205, 204, 3008
# The bus(es) 103, 154, 205 reported violations for the bus fault BUS 153
# The bus(es) 204, 3008 reported violations for the bus fault BUS 203
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   4 151-152(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 600 MW, Wind = 40 MW, HLS
# For the studied scenario Solar = 100 MW, Hydro = 600 MW, Wind = 40 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 103, 153, 204, 205, 3006, 3007, 3008, 3009, 3010, 3012
# The bus(es) 103, 154, 205 reported violations for the bus fault BUS 153
# The bus(es) 204, 3008 reported violations for the bus fault BUS 203
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   4 151-152(1)
# The bus(es) 103, 153, 204, 205, 3006, 3007, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Solar = 100 MW, Hydro = 600 MW, Wind = 75 MW, HLS
# For the studied scenario Solar = 100 MW, Hydro = 600 MW, Wind = 75 MW, HLS, the bus(es) reporting lower emergency range violation(s) are the bus(es) 154, 103, 153, 204, 205, 3006, 3007, 3008, 3009, 3010, 3012
# The bus(es) 103, 154, 205 reported violations for the bus fault BUS 153
# The bus(es) 204, 3008 reported violations for the bus fault BUS 203
# The bus(es) 154 reported violations for the single line open fault SING OPN LIN   4 151-152(1)
# The bus(es) 103, 153, 204, 205, 3006, 3007, 3008, 3009, 3010, 3012 reported violations for the single line open fault SING OPN LIN   6 152-153(1)
# ------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Lower Voltage Limit Counts - Scenario

# %%
vl_index = list(data_low['Scenario'].value_counts().index)
vl_counts = list(data_low['Scenario'].value_counts())
dict_vl_count = {
    'Scenario':vl_index,
    'Violation Counts':vl_counts
}
scen_lv_vc  = pd.DataFrame(dict_vl_count)
scen_lv_vc
# Out:
#                                              Scenario  Violation Counts
# 0    Solar = 50 MW, Hydro = 400 MW, Wind = 75 MW, LLS                78
# 1    Solar = 50 MW, Hydro = 400 MW, Wind = 40 MW, LLS                70
# 2     Solar = 50 MW, Hydro = 400 MW, Wind = 0 MW, LLS                70
# 3      Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, HLS                66
# 4     Solar = 0 MW, Hydro = 400 MW, Wind = 40 MW, HLS                66
# ..                                                ...               ...
# 76  Solar = 100 MW, Hydro = 600 MW, Wind = 40 MW, LLS                 6
# 77     Solar = 0 MW, Hydro = 500 MW, Wind = 0 MW, LLS                 2
# 78   Solar = 50 MW, Hydro = 500 MW, Wind = 40 MW, LLS                 2
# 79    Solar = 0 MW, Hydro = 500 MW, Wind = 75 MW, LLS                 2
# 80    Solar = 0 MW, Hydro = 500 MW, Wind = 40 MW, LLS                 2
#
# [81 rows x 2 columns]

# %% [markdown]
# Lower Voltage Limit Counts - Bus

# %%
vlb_index = list([i.strip().split()[0] for i in data_low['Bus'].value_counts().index])
vlb_counts = list(data_low['Bus'].value_counts())
dict_vlb_count = {
    'Bus':vlb_index,
    'Violation Counts':vlb_counts
}
bus_lv_vc  = pd.DataFrame(dict_vlb_count)
bus_lv_vc
# Out:
#      Bus  Violation Counts
# 0    154               520
# 1    205               350
# 2   3008               316
# 3    103               306
# 4   3007               224
# 5    204               220
# 6    153               128
# 7    203               122
# 8   3012               106
# 9   3006               100
# 10  3009                80
# 11  3010                76
# 12  3018                56
# 13   202                36
# 14   152                24
# 15   206                20
# 16  3005                20
# 17  3004                 8

# %% [markdown]
# Lower Voltage Limit Counts - Contingency

# %%
vlc_index = list(data_low['Contingency'].value_counts().index)
vlc_counts = list(data_low['Contingency'].value_counts())
dict_vlc_count = {
    'Contingency':vlc_index,
    'Violation Counts':vlc_counts
}
cont_lv_vc  = pd.DataFrame(dict_vlc_count)
cont_lv_vc
# Out:
#                      Contingency  Violation Counts
# 0    SING OPN LIN   6 152-153(1)               522
# 1                       BUS 3005               446
# 2   SING OPN LIN   10 201-202(1)               446
# 3                        BUS 205               370
# 4                        BUS 203               224
# 5                    UNIT 206(1)               136
# 6                        BUS 153               126
# 7   SING OPN LIN   20 205-206(1)               116
# 8                        BUS 202               102
# 9   SING OPN LIN   11 201-204(1)                92
# 10                       BUS 204                74
# 11                      BUS 3004                24
# 12   SING OPN LIN   4 151-152(1)                12
# 13   SING OPN LIN   5 151-152(2)                12
# 14                      BUS 3003                10

# %% [markdown]
# Lower Voltage Result Summary - grouped by Scenario and Contingency

# %%
data_fil_lv = data_low[['Scenario', 'Bus Number', 'Contingency']].drop_duplicates()
pivot_lv = pd.DataFrame(pd.pivot(data_fil_lv, index= ['Scenario','Contingency'], columns = 'Bus Number',values = 'Bus Number').to_records())
pivot_lv['Buses'] = pivot_lv['103'].astype(str).str.cat(pivot_lv[['152', '153', '154', '202', '203',
       '204', '205', '206', '3004', '3005', '3006', '3007', '3008', '3018']].astype(str), sep=',')
pivot_lv['Buses'] =pivot_lv['Buses'].str.replace(',nan','').str.replace('nan,','')
pivot_low = pivot_lv.drop(columns = list(data_fil_lv['Bus Number'].unique()))

# %%
pivot_table_lv = pd.DataFrame(pd.pivot_table(data_fil_lv, index= ['Scenario','Contingency'],values = 'Bus Number', aggfunc='count').to_records())
pivot_table_low = pivot_table_lv.rename(columns = {'Bus Number':'Bus Count'})
df_low = pd.merge(pivot_low, pivot_table_low, on=['Scenario','Contingency'], how='inner').sort_values(by='Bus Count', ascending=False).reset_index(drop=True)
df_low.head(60)
# Out:
#                                              Scenario  \
# 0     Solar = 50 MW, Hydro = 500 MW, Wind = 0 MW, LLS
# 1   Solar = 100 MW, Hydro = 500 MW, Wind = 40 MW, LLS
# 2   Solar = 100 MW, Hydro = 500 MW, Wind = 75 MW, LLS
# 3    Solar = 50 MW, Hydro = 400 MW, Wind = 75 MW, RLS
# 4   Solar = 100 MW, Hydro = 600 MW, Wind = 75 MW, RLS
# 5   Solar = 100 MW, Hydro = 600 MW, Wind = 40 MW, RLS
# 6    Solar = 100 MW, Hydro = 600 MW, Wind = 0 MW, RLS
# 7     Solar = 0 MW, Hydro = 400 MW, Wind = 40 MW, HLS
# 8      Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, HLS
# 9    Solar = 100 MW, Hydro = 500 MW, Wind = 0 MW, LLS
# 10    Solar = 50 MW, Hydro = 400 MW, Wind = 0 MW, HLS
# 11   Solar = 50 MW, Hydro = 400 MW, Wind = 40 MW, RLS
# 12    Solar = 50 MW, Hydro = 400 MW, Wind = 0 MW, RLS
# 13  Solar = 100 MW, Hydro = 400 MW, Wind = 75 MW, RLS
# 14   Solar = 50 MW, Hydro = 400 MW, Wind = 75 MW, HLS
# 15   Solar = 50 MW, Hydro = 400 MW, Wind = 40 MW, HLS
# 16    Solar = 0 MW, Hydro = 500 MW, Wind = 75 MW, HLS
# 17  Solar = 100 MW, Hydro = 600 MW, Wind = 75 MW, HLS
# 18  Solar = 100 MW, Hydro = 400 MW, Wind = 40 MW, RLS
# 19     Solar = 0 MW, Hydro = 500 MW, Wind = 0 MW, HLS
# 20    Solar = 0 MW, Hydro = 500 MW, Wind = 40 MW, HLS
# 21   Solar = 100 MW, Hydro = 400 MW, Wind = 0 MW, RLS
# 22  Solar = 100 MW, Hydro = 600 MW, Wind = 40 MW, HLS
# 23    Solar = 0 MW, Hydro = 600 MW, Wind = 75 MW, RLS
# 24    Solar = 50 MW, Hydro = 500 MW, Wind = 0 MW, HLS
# 25    Solar = 0 MW, Hydro = 500 MW, Wind = 75 MW, RLS
# 26     Solar = 0 MW, Hydro = 600 MW, Wind = 0 MW, RLS
# 27    Solar = 0 MW, Hydro = 600 MW, Wind = 40 MW, RLS
# 28  Solar = 100 MW, Hydro = 500 MW, Wind = 40 MW, HLS
# 29   Solar = 100 MW, Hydro = 500 MW, Wind = 0 MW, HLS
# 30  Solar = 100 MW, Hydro = 500 MW, Wind = 75 MW, HLS
# 31   Solar = 50 MW, Hydro = 500 MW, Wind = 40 MW, HLS
# 32     Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, LLS
# 33   Solar = 50 MW, Hydro = 500 MW, Wind = 75 MW, HLS
# 34  Solar = 100 MW, Hydro = 400 MW, Wind = 75 MW, HLS
# 35    Solar = 0 MW, Hydro = 400 MW, Wind = 40 MW, HLS
# 36  Solar = 100 MW, Hydro = 400 MW, Wind = 40 MW, HLS
# 37    Solar = 50 MW, Hydro = 400 MW, Wind = 0 MW, HLS
# 38   Solar = 100 MW, Hydro = 400 MW, Wind = 0 MW, HLS
# 39    Solar = 0 MW, Hydro = 400 MW, Wind = 75 MW, LLS
# 40    Solar = 0 MW, Hydro = 400 MW, Wind = 75 MW, HLS
# 41    Solar = 50 MW, Hydro = 600 MW, Wind = 0 MW, RLS
# 42     Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, HLS
# 43     Solar = 0 MW, Hydro = 500 MW, Wind = 0 MW, RLS
# 44   Solar = 50 MW, Hydro = 400 MW, Wind = 75 MW, LLS
# 45    Solar = 0 MW, Hydro = 400 MW, Wind = 40 MW, LLS
# 46   Solar = 100 MW, Hydro = 400 MW, Wind = 0 MW, LLS
# 47    Solar = 0 MW, Hydro = 500 MW, Wind = 40 MW, RLS
# 48    Solar = 50 MW, Hydro = 400 MW, Wind = 0 MW, LLS
# 49   Solar = 50 MW, Hydro = 400 MW, Wind = 40 MW, LLS
# 50   Solar = 100 MW, Hydro = 600 MW, Wind = 0 MW, RLS
# 51    Solar = 0 MW, Hydro = 600 MW, Wind = 40 MW, RLS
# 52    Solar = 0 MW, Hydro = 400 MW, Wind = 40 MW, HLS
# 53  Solar = 100 MW, Hydro = 500 MW, Wind = 40 MW, HLS
# 54     Solar = 0 MW, Hydro = 600 MW, Wind = 0 MW, RLS
# 55   Solar = 50 MW, Hydro = 500 MW, Wind = 40 MW, HLS
# 56   Solar = 50 MW, Hydro = 400 MW, Wind = 75 MW, LLS
# 57     Solar = 0 MW, Hydro = 400 MW, Wind = 0 MW, HLS
# 58   Solar = 50 MW, Hydro = 500 MW, Wind = 75 MW, HLS
# 59   Solar = 100 MW, Hydro = 500 MW, Wind = 0 MW, HLS
#
#                      Contingency  \
# 0                        BUS 205
# 1                        BUS 205
# 2                        BUS 205
# 3                        BUS 205
# 4   SING OPN LIN   10 201-202(1)
# 5   SING OPN LIN   10 201-202(1)
# 6   SING OPN LIN   10 201-202(1)
# 7   SING OPN LIN   10 201-202(1)
# 8   SING OPN LIN   10 201-202(1)
# 9                        BUS 205
# 10  SING OPN LIN   10 201-202(1)
# 11                       BUS 205
# 12                       BUS 205
# 13                       BUS 205
# 14  SING OPN LIN   10 201-202(1)
# 15  SING OPN LIN   10 201-202(1)
# 16   SING OPN LIN   6 152-153(1)
# 17   SING OPN LIN   6 152-153(1)
# 18                       BUS 205
# 19   SING OPN LIN   6 152-153(1)
# 20   SING OPN LIN   6 152-153(1)
# 21                       BUS 205
# 22   SING OPN LIN   6 152-153(1)
# 23   SING OPN LIN   6 152-153(1)
# 24   SING OPN LIN   6 152-153(1)
# 25  SING OPN LIN   10 201-202(1)
# 26   SING OPN LIN   6 152-153(1)
# 27   SING OPN LIN   6 152-153(1)
# 28   SING OPN LIN   6 152-153(1)
# 29   SING OPN LIN   6 152-153(1)
# 30   SING OPN LIN   6 152-153(1)
# 31   SING OPN LIN   6 152-153(1)
# 32                       BUS 205
# 33   SING OPN LIN   6 152-153(1)
# 34  SING OPN LIN   10 201-202(1)
# 35   SING OPN LIN   6 152-153(1)
# 36  SING OPN LIN   10 201-202(1)
# 37   SING OPN LIN   6 152-153(1)
# 38  SING OPN LIN   10 201-202(1)
# 39                       BUS 205
# 40   SING OPN LIN   6 152-153(1)
# 41   SING OPN LIN   6 152-153(1)
# 42   SING OPN LIN   6 152-153(1)
# 43  SING OPN LIN   10 201-202(1)
# 44                   UNIT 206(1)
# 45                       BUS 205
# 46                   UNIT 206(1)
# 47  SING OPN LIN   10 201-202(1)
# 48                   UNIT 206(1)
# 49                   UNIT 206(1)
# 50   SING OPN LIN   6 152-153(1)
# 51                      BUS 3005
# 52                      BUS 3005
# 53                      BUS 3005
# 54                      BUS 3005
# 55                      BUS 3005
# 56  SING OPN LIN   20 205-206(1)
# 57                      BUS 3005
# 58                      BUS 3005
# 59                      BUS 3005
#
#                                                 Buses  Bus Count
# 0   103,152,153,154,202,203,3004,3005,3006,3007,30...         15
# 1   103,152,153,154,202,203,3004,3005,3006,3007,30...         15
# 2   103,152,153,154,202,203,3004,3005,3006,3007,30...         15
# 3   103,152,153,154,202,203,3004,3005,3006,3007,30...         15
# 4      103,152,153,154,202,203,204,205,3006,3007,3008         14
# 5      103,152,153,154,202,203,204,205,3006,3007,3008         14
# 6      103,152,153,154,202,203,204,205,3006,3007,3008         14
# 7      103,152,153,154,202,203,204,205,3006,3007,3008         14
# 8      103,152,153,154,202,203,204,205,3006,3007,3008         14
# 9        103,152,153,154,203,3005,3006,3007,3008,3018         13
# 10         103,153,154,202,203,204,205,3006,3007,3008         13
# 11       103,152,153,154,203,3005,3006,3007,3008,3018         13
# 12       103,152,153,154,203,3005,3006,3007,3008,3018         13
# 13           103,153,154,203,3005,3006,3007,3008,3018         12
# 14         103,153,154,202,203,204,205,3006,3007,3008         12
# 15         103,153,154,202,203,204,205,3006,3007,3008         11
# 16                 103,153,154,204,205,3006,3007,3008         11
# 17                 103,153,154,204,205,3006,3007,3008         11
# 18                103,153,154,203,3005,3006,3007,3008         11
# 19                 103,153,154,204,205,3006,3007,3008         11
# 20                 103,153,154,204,205,3006,3007,3008         11
# 21                103,153,154,203,3005,3006,3007,3008         11
# 22                 103,153,154,204,205,3006,3007,3008         11
# 23                      103,153,154,204,205,3006,3008         10
# 24                      103,153,154,204,205,3006,3008         10
# 25              103,153,154,202,203,204,205,3007,3008         10
# 26                      103,153,154,204,205,3006,3008         10
# 27                      103,153,154,204,205,3006,3008         10
# 28                      103,153,154,204,205,3006,3008         10
# 29                      103,153,154,204,205,3006,3008         10
# 30                      103,153,154,204,205,3006,3008         10
# 31                      103,153,154,204,205,3006,3008         10
# 32                     103,153,154,203,3006,3007,3008         10
# 33                      103,153,154,204,205,3006,3008         10
# 34              103,153,154,202,203,204,205,3007,3008         10
# 35                          103,153,154,205,3006,3008          9
# 36              103,153,154,202,203,204,205,3007,3008          9
# 37                          103,153,154,205,3006,3008          9
# 38              103,153,154,202,203,204,205,3007,3008          9
# 39                     103,153,154,203,3006,3007,3008          9
# 40                          103,153,154,205,3006,3008          9
# 41                          103,153,154,205,3006,3008          9
# 42                          103,153,154,205,3006,3008          9
# 43              103,153,154,202,203,204,205,3007,3008          9
# 44                  103,154,203,204,205,206,3007,3008          8
# 45                     103,153,154,203,3006,3007,3008          8
# 46                  103,154,203,204,205,206,3007,3008          8
# 47                   103,153,154,202,203,204,205,3008          8
# 48                  103,154,203,204,205,206,3007,3008          8
# 49                  103,154,203,204,205,206,3007,3008          8
# 50                                   153,154,205,3006          7
# 51                     103,154,204,205,3007,3008,3018          7
# 52                     103,154,204,205,3007,3008,3018          7
# 53                     103,154,204,205,3007,3008,3018          7
# 54                     103,154,204,205,3007,3008,3018          7
# 55                     103,154,204,205,3007,3008,3018          7
# 56                      103,154,203,204,205,3007,3008          7
# 57                     103,154,204,205,3007,3008,3018          7
# 58                     103,154,204,205,3007,3008,3018          7
# 59                     103,154,204,205,3007,3008,3018          7
